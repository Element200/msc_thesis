# %%
import sys
sys.path.append("C:/Users/siddh/Desktop/Graduate files/Research/mpemba_functions")

import mpemba

# %%
kumarian_potential = mpemba.special_potentials.AsymmetricDoubleWellPotential(x_max=9)
kumarian_ensemble = mpemba.construct_simulated_ensemble(kumarian_potential, k_BTs=[1000,12,1], num_particles=10_000)
# Out:
# 100%|██████████| 9999/9999 [00:07<00:00, 1345.91it/s]
# 100%|██████████| 9999/9999 [00:12<00:00, 770.00it/s]
# 100%|██████████| 9999/9999 [00:07<00:00, 1408.77it/s]

# %%
distances = kumarian_ensemble.get_distances(use_true_distro=True)
energies = kumarian_ensemble.get_average_energy(normalise_by_final=True)

plt.plot(ensemble.times, distances)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 distances = kumarian_ensemble.get_distances(use_true_distro=True)
#       2 energies = kumarian_ensemble.get_average_energy(normalise_by_final=True)
# ----> 4 plt.plot(ensemble.times, distances)
#
# NameError: name 'plt' is not defined

# %%
plt.plot(ensemble.times, energies)

# %%
df = pd.read
